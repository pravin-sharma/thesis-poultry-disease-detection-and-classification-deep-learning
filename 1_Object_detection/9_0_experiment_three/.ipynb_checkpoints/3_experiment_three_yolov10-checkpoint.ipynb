# %%
# !python --version
# Out:
# Python 3.9.19

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...

# %%
# # Google Colab Specific commands
from google.colab import drive
drive.mount('/content/drive')
# # # Example: Unzip into the current working directory - since i have a zip in my drive and i want to unzip into my colab env for faster access
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/pravin_thesis/1_yolov10_object_detection/dataset.zip" -d '/content/yolov10/datasets/'
# Out:
# Mounted at /content/drive

# %%
cd yolov10
# Out:
# C:\Users\pravi\OneDrive\Desktop\Pravin\Study\Masters\Research Project\code\9_experiment_three\yolov10
# C:\ProgramData\anaconda3\envs\py39\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install .
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing c:\users\pravi\onedrive\desktop\pravin\study\masters\research project\code\9_experiment_three\yolov10
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=735276 sha256=5ae86add13c74e47cbd4743a9cc3b4c97c55472b4715dc4f30a9d03087483956
#   Stored in directory: C:\Users\pravi\AppData\Local\Temp\pip-ephem-wheel-cache-q_7j5ybe\wheels\d7\57\c7\195ab07232354886e33e80cde6a1c87c2b8e3a7350d3f5ac98
# Successfully built ultralytics
# ...

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    # "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded C:\Users\pravi\OneDrive\Desktop\Pravin\Study\Masters\Research Project\code\9_experiment_three\yolov10\weights\yolov10n.pt

# %% [markdown]
# ## Training

# %%
# !yolo task=detect mode=train epochs=100 batch=16 plots=True model=weights/yolov10n.pt data=./datasets/data.yaml patience=20
# Out:
# New https://pypi.org/project/ultralytics/8.2.50 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Google Colab specific code
# Copy run results to google drive
# !cp -r ./runs "../drive/MyDrive/Colab Notebooks/pravin_thesis/1_yolov10_object_detection/results"

# %% [markdown]
# ## Prediction

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=./runs/detect/train/weights/best.pt source=./datasets/dataset/test/images/ plots=True
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.9.19 torch-2.3.1+cpu CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLOv10n summary (fused): 285 layers, 2695976 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/2249 C:\Users\pravi\OneDrive\Desktop\Pravin\Study\Masters\Research Project\code\9_experiment_three\yolov10\datasets\dataset\test\images\cocci.1003.jpg: 640x640 2 coccis, 167.7ms
# image 2/2249 C:\Users\pravi\OneDrive\Desktop\Pravin\Study\Masters\Research Project\code\9_experiment_three\yolov10\datasets\dataset\test\images\cocci.1004.jpg: 640x640 1 cocci, 181.8ms
# image 3/2249 C:\Users\pravi\OneDrive\Desktop\Pravin\Study\Masters\Research Project\code\9_experiment_three\yolov10\datasets\dataset\test\images\cocci.1006.jpg: 640x640 1 cocci, 156.8ms
# image 4/2249 C:\Users\pravi\OneDrive\Desktop\Pravin\Study\Masters\Research Project\code\9_experiment_three\yolov10\datasets\dataset\test\images\cocci.1017.jpg: 640x640 1 cocci, 188.8ms
# ...

# %%
# from yolov10 import YOLO

# # Load the trained model weights
# model_path = 'weights/yolov10n.pt'
# model = YOLO(model_path)
