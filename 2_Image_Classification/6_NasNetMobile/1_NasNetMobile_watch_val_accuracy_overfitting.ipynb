# %%
# # Google Colab Specific commands
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # # Example: Unzip into the current working directory - since i have a zip in my drive and i want to unzip into my colab env for faster access
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/pravin_thesis/0_dataset/11_balanced_class_subfolder_no_label.zip" -d '/content/dataset/'

# %%
# !pip install keras_cv rasterio
# Out:
# Collecting keras_cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_cv) (24.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras_cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras_cv) (2024.5.15)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras_cv) (4.9.6)
# Collecting keras-core (from keras_cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras_cv) (0.2.8)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.7.4)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (71.0.4)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (4.66.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (13.7.1)
# Collecting namex (from keras-core->keras_cv)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (3.11.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (0.1.8)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (3.20.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (14.0.2)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.1.5)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.4.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.14.1)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (1.7.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (2024.6.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (6.4.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (2.0.7)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (2.16.1)
# Requirement already satisfied: docstring-parser~=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras_cv) (0.16)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 44.4 MB/s eta 0:00:00
# Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 93.4 MB/s eta 0:00:00
# Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 58.3 MB/s eta 0:00:00
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Installing collected packages: namex, snuggs, affine, rasterio, keras-core, keras_cv
# Successfully installed affine-2.4.0 keras-core-0.1.7 keras_cv-0.9.0 namex-0.0.8 rasterio-1.3.10 snuggs-1.4.7

# %%
# Standard Library Imports
import os
import random
import shutil
import warnings
# Data Analysis and Manipulation
import pandas as pd
import numpy as np
# Image Processing
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import rasterio
from PIL import Image
import PIL
# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
# Machine Learning and Deep Learning
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.utils import image_dataset_from_directory
from keras.optimizers import AdamW
import keras_cv
keras.mixed_precision.set_global_policy("mixed_float16")
# Progress Bars
import tqdm
from tqdm.auto import trange, tqdm
# Evaluation Metrics
import sklearn
from sklearn.metrics import precision_score, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
# Out:
# Using TensorFlow backend

# %%
IMAGE_SIZE = (224,224) #For EfficentNetV2B2
BATCH_SIZE = 32
COLOR_MODE = "rgb"
SHUFFLE = True
TRAIN_PATH = "/content/dataset/"
SEED = 4224
AUTOTUNE = tf.data.experimental.AUTOTUNE
NUM_CLASSES = 4
NUM_EPOCHS = 50
INITIAL_LEARNING_RATE = 0.0001

# %%
IMAGE_SIZE
# Out:
# (224, 224)

# %%
def load_batches(imgsz: tuple, bsz: int, clr: str, shuffle: bool, path_: str, seed: int):
    try:
        batch_1, batch_2 = image_dataset_from_directory(
            image_size=imgsz,
            directory=path_,
            color_mode=clr,
            shuffle=shuffle,
            validation_split=0.2,
            subset="both",
            seed=seed,
            labels="inferred",
            batch_size=bsz,
            class_names=None,
            interpolation="bilinear",
            crop_to_aspect_ratio=True
        )
        return batch_1, batch_2
    except ValueError as e:
        print(f"Error loading data from directory {path_}: {str(e)}")
        return None, None

train_batch, valid_batch = load_batches(imgsz=IMAGE_SIZE, bsz=BATCH_SIZE, clr=COLOR_MODE, shuffle=SHUFFLE, path_=TRAIN_PATH, seed=SEED)
if train_batch is None:
    print("Failed to load training batch. Check directory and file formats.")
# Out:
# Found 11240 files belonging to 4 classes.
# Using 8992 files for training.
# Using 2248 files for validation.

# %%
train_batch.class_names
# Out:
# ['cocci', 'healthy', 'ncd', 'salmo']

# %%
def rescale_imgs(img_, lbl_):
    img_ = tf.cast(img_, tf.float32)
    return img_/255.0, lbl_

train_batch = train_batch.map(rescale_imgs, num_parallel_calls = tf.data.AUTOTUNE)
valid_batch = valid_batch.map(rescale_imgs, num_parallel_calls = tf.data.AUTOTUNE)

# %%
def augment_img(img_, lbl_):
    image = tf.image.random_flip_left_right(img_)
    image = tf.image.central_crop(image, 0.85)
    image = tf.image.resize(image, IMAGE_SIZE)
    image = tf.image.random_brightness(image, 0.2)
    image = tf.image.random_contrast(image, 0.5, 2.0)
    return tf.cast(image, tf.float32), lbl_

train_batch = train_batch.map(augment_img, tf.data.AUTOTUNE)
train_batch = train_batch.cache().prefetch(buffer_size = tf.data.AUTOTUNE)
valid_batch = valid_batch.cache().prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
len(valid_batch) * 32
# Out:
# 2272

# %%
def val_batch_class_distribution(valid_batch):
    images = list()
    labels = list()

    for img, lbl in valid_batch.unbatch():
        images.append(img)
        if lbl == 0:
            labels.append("Coccidiosis")
        elif lbl == 1:
            labels.append("Healthy")
        elif lbl == 2:
            labels.append("Newcastle Disease")
        else:
            labels.append("Salmo")
    images = np.array(images)
    labels = np.array(labels)

    print(f'Coccidiosis Percentage: {np.mean(labels == "Coccidiosis")}')
    print(f'Healthy Percentage: {np.mean(labels == "Healthy")}')
    print(f'Newcastle Disease Percentage: {np.mean(labels == "Newcastle Disease")}')
    print(f'Salmo Percentage: {np.mean(labels == "Salmo")}')
    return labels

labels_ = val_batch_class_distribution(valid_batch)
# Out:
# Coccidiosis Percentage: 0.2611209964412811
# Healthy Percentage: 0.24332740213523132
# Newcastle Disease Percentage: 0.2557829181494662
# Salmo Percentage: 0.23976868327402134

# %%
weights_ = class_weight.compute_class_weight("balanced", classes = ['coccidiosis', 'healthy', 'newcastle disease', 'salmo'], y = [i.lower() for i in labels_])
weight_dict = {}
for i, j in enumerate(weights_):
    weight_dict[i] = j
weight_dict
# Out:
# {0: 0.9574105621805792,
#  1: 1.0274223034734917,
#  2: 0.9773913043478261,
#  3: 1.0426716141001855}

# %%
def create_nasnetmobile_model():
    from keras.applications import NASNetMobile
    # from keras.applications.nasnet import preprocess_input
    from tensorflow.keras.layers import Dense
    from tensorflow.keras.models import Model

    pre_model = NASNetMobile(input_shape=(224,224, 3),
                   include_top=False,
                   weights='imagenet',
                   pooling='avg')
    pre_model.trainable = False

    inputs = pre_model.input
    x = Dense(64, activation='relu')(pre_model.output)
    x = Dense(64, activation='relu')(x)
    outputs = Dense(4, activation='softmax')(x)

    model = Model(inputs=inputs, outputs=outputs)
    initial_learning_rate = INITIAL_LEARNING_RATE
    optimizer = keras.optimizers.AdamW(learning_rate = initial_learning_rate)
    model.compile(optimizer = optimizer,
                  loss = keras.losses.SparseCategoricalCrossentropy(),
                  metrics = ["accuracy"])

    return model

# %%
nasnetmobile_model = create_nasnetmobile_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 [==============================] - 2s 0us/step

# %%
# keras.utils.plot_model(nasnetmobile_model, to_file = "nasnetmobile_model_architecture.png", show_shapes = True)

# %%
nasnetmobile_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  stem_conv1 (Conv2D)         (None, 111, 111, 32)         864       ['input_1[0][0]']
#
#  stem_bn1 (BatchNormalizati  (None, 111, 111, 32)         128       ['stem_conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 111, 111, 32)         0         ['stem_bn1[0][0]']
#
#  reduction_conv_1_stem_1 (C  (None, 111, 111, 11)         352       ['activation[0][0]']
#  onv2D)
#
#  reduction_bn_1_stem_1 (Bat  (None, 111, 111, 11)         44        ['reduction_conv_1_stem_1[0][0
#  chNormalization)                                                   ]']
#
#  activation_1 (Activation)   (None, 111, 111, 11)         0         ['reduction_bn_1_stem_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 111, 111, 32)         0         ['stem_bn1[0][0]']
#
#  separable_conv_1_pad_reduc  (None, 115, 115, 11)         0         ['activation_1[0][0]']
#  tion_left1_stem_1 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 117, 117, 32)         0         ['activation_3[0][0]']
#  tion_right1_stem_1 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 56, 56, 11)           396       ['separable_conv_1_pad_reducti
#  _left1_stem_1 (SeparableCo                                         on_left1_stem_1[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 56, 56, 11)           1920      ['separable_conv_1_pad_reducti
#  _right1_stem_1 (SeparableC                                         on_right1_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_1_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_1_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)   (None, 56, 56, 11)           0         ['separable_conv_1_bn_reductio
#                                                                     n_left1_stem_1[0][0]']
#
#  activation_4 (Activation)   (None, 56, 56, 11)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right1_stem_1[0][0]']
#
#  separable_conv_2_reduction  (None, 56, 56, 11)           396       ['activation_2[0][0]']
#  _left1_stem_1 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 56, 56, 11)           660       ['activation_4[0][0]']
#  _right1_stem_1 (SeparableC
#  onv2D)
#
#  activation_5 (Activation)   (None, 111, 111, 32)         0         ['stem_bn1[0][0]']
#
#  separable_conv_2_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_2_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_2_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 117, 117, 32)         0         ['activation_5[0][0]']
#  tion_right2_stem_1 (ZeroPa
#  dding2D)
#
#  activation_7 (Activation)   (None, 111, 111, 32)         0         ['stem_bn1[0][0]']
#
#  reduction_add_1_stem_1 (Ad  (None, 56, 56, 11)           0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_1[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_1[0][0]']
#
#  separable_conv_1_reduction  (None, 56, 56, 11)           1920      ['separable_conv_1_pad_reducti
#  _right2_stem_1 (SeparableC                                         on_right2_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 115, 115, 32)         0         ['activation_7[0][0]']
#  tion_right3_stem_1 (ZeroPa
#  dding2D)
#
#  activation_9 (Activation)   (None, 56, 56, 11)           0         ['reduction_add_1_stem_1[0][0]
#                                                                     ']
#
#  separable_conv_1_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_1_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 56, 56, 11)           1152      ['separable_conv_1_pad_reducti
#  _right3_stem_1 (SeparableC                                         on_right3_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 56, 56, 11)           220       ['activation_9[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  activation_6 (Activation)   (None, 56, 56, 11)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_1_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_1_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_pad_1_stem_1 (Ze  (None, 113, 113, 11)         0         ['reduction_bn_1_stem_1[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 56, 56, 11)           660       ['activation_6[0][0]']
#  _right2_stem_1 (SeparableC
#  onv2D)
#
#  activation_8 (Activation)   (None, 56, 56, 11)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right3_stem_1[0][0]']
#
#  activation_10 (Activation)  (None, 56, 56, 11)           0         ['separable_conv_1_bn_reductio
#                                                                     n_left4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (Ma  (None, 56, 56, 11)           0         ['reduction_pad_1_stem_1[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_2_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 56, 56, 11)           396       ['activation_8[0][0]']
#  _right3_stem_1 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 56, 56, 11)           220       ['activation_10[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_stem_2 (Acti  (None, 111, 111, 32)         0         ['stem_bn1[0][0]']
#  vation)
#
#  reduction_add_2_stem_1 (Ad  (None, 56, 56, 11)           0         ['reduction_left2_stem_1[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Av  (None, 56, 56, 11)           0         ['reduction_pad_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_2_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  reduction_left4_stem_1 (Av  (None, 56, 56, 11)           0         ['reduction_add_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 56, 56, 11)           44        ['separable_conv_2_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_right5_stem_1 (M  (None, 56, 56, 11)           0         ['reduction_pad_1_stem_1[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d (ZeroPaddin  (None, 112, 112, 32)         0         ['adjust_relu_1_stem_2[0][0]']
#  g2D)
#
#  reduction_add3_stem_1 (Add  (None, 56, 56, 11)           0         ['reduction_left3_stem_1[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_1[0][0]']
#
#  add (Add)                   (None, 56, 56, 11)           0         ['reduction_add_2_stem_1[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_1[0][0]
#                                                                     ']
#
#  reduction_add4_stem_1 (Add  (None, 56, 56, 11)           0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_1[0][0]',
#                                                                      'reduction_right5_stem_1[0][0
#                                                                     ]']
#
#  cropping2d (Cropping2D)     (None, 111, 111, 32)         0         ['zero_padding2d[0][0]']
#
#  reduction_concat_stem_1 (C  (None, 56, 56, 44)           0         ['reduction_add_2_stem_1[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_1[0][0]'
#                                                                     , 'add[0][0]',
#                                                                      'reduction_add4_stem_1[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_stem_2 (  (None, 56, 56, 32)           0         ['adjust_relu_1_stem_2[0][0]']
#  AveragePooling2D)
#
#  adjust_avg_pool_2_stem_2 (  (None, 56, 56, 32)           0         ['cropping2d[0][0]']
#  AveragePooling2D)
#
#  activation_11 (Activation)  (None, 56, 56, 44)           0         ['reduction_concat_stem_1[0][0
#                                                                     ]']
#
#  adjust_conv_1_stem_2 (Conv  (None, 56, 56, 11)           352       ['adjust_avg_pool_1_stem_2[0][
#  2D)                                                                0]']
#
#  adjust_conv_2_stem_2 (Conv  (None, 56, 56, 11)           352       ['adjust_avg_pool_2_stem_2[0][
#  2D)                                                                0]']
#
#  reduction_conv_1_stem_2 (C  (None, 56, 56, 22)           968       ['activation_11[0][0]']
#  onv2D)
#
#  concatenate (Concatenate)   (None, 56, 56, 22)           0         ['adjust_conv_1_stem_2[0][0]',
#                                                                      'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (Bat  (None, 56, 56, 22)           88        ['reduction_conv_1_stem_2[0][0
#  chNormalization)                                                   ]']
#
#  adjust_bn_stem_2 (BatchNor  (None, 56, 56, 22)           88        ['concatenate[0][0]']
#  malization)
#
#  activation_12 (Activation)  (None, 56, 56, 22)           0         ['reduction_bn_1_stem_2[0][0]'
#                                                                     ]
#
#  activation_14 (Activation)  (None, 56, 56, 22)           0         ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_1_pad_reduc  (None, 59, 59, 22)           0         ['activation_12[0][0]']
#  tion_left1_stem_2 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 61, 61, 22)           0         ['activation_14[0][0]']
#  tion_right1_stem_2 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 28, 28, 22)           1034      ['separable_conv_1_pad_reducti
#  _left1_stem_2 (SeparableCo                                         on_left1_stem_2[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 28, 28, 22)           1562      ['separable_conv_1_pad_reducti
#  _right1_stem_2 (SeparableC                                         on_right1_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_1_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_1_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  activation_13 (Activation)  (None, 28, 28, 22)           0         ['separable_conv_1_bn_reductio
#                                                                     n_left1_stem_2[0][0]']
#
#  activation_15 (Activation)  (None, 28, 28, 22)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right1_stem_2[0][0]']
#
#  separable_conv_2_reduction  (None, 28, 28, 22)           1034      ['activation_13[0][0]']
#  _left1_stem_2 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 28, 28, 22)           1562      ['activation_15[0][0]']
#  _right1_stem_2 (SeparableC
#  onv2D)
#
#  activation_16 (Activation)  (None, 56, 56, 22)           0         ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_2_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_2_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_2_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 61, 61, 22)           0         ['activation_16[0][0]']
#  tion_right2_stem_2 (ZeroPa
#  dding2D)
#
#  activation_18 (Activation)  (None, 56, 56, 22)           0         ['adjust_bn_stem_2[0][0]']
#
#  reduction_add_1_stem_2 (Ad  (None, 28, 28, 22)           0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_2[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_2[0][0]']
#
#  separable_conv_1_reduction  (None, 28, 28, 22)           1562      ['separable_conv_1_pad_reducti
#  _right2_stem_2 (SeparableC                                         on_right2_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 59, 59, 22)           0         ['activation_18[0][0]']
#  tion_right3_stem_2 (ZeroPa
#  dding2D)
#
#  activation_20 (Activation)  (None, 28, 28, 22)           0         ['reduction_add_1_stem_2[0][0]
#                                                                     ']
#
#  separable_conv_1_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_1_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 28, 28, 22)           1034      ['separable_conv_1_pad_reducti
#  _right3_stem_2 (SeparableC                                         on_right3_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 28, 28, 22)           682       ['activation_20[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  activation_17 (Activation)  (None, 28, 28, 22)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_1_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_1_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_pad_1_stem_2 (Ze  (None, 57, 57, 22)           0         ['reduction_bn_1_stem_2[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 28, 28, 22)           1562      ['activation_17[0][0]']
#  _right2_stem_2 (SeparableC
#  onv2D)
#
#  activation_19 (Activation)  (None, 28, 28, 22)           0         ['separable_conv_1_bn_reductio
#                                                                     n_right3_stem_2[0][0]']
#
#  activation_21 (Activation)  (None, 28, 28, 22)           0         ['separable_conv_1_bn_reductio
#                                                                     n_left4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (Ma  (None, 28, 28, 22)           0         ['reduction_pad_1_stem_2[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_2_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 28, 28, 22)           1034      ['activation_19[0][0]']
#  _right3_stem_2 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 28, 28, 22)           682       ['activation_21[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_0 (Activatio  (None, 56, 56, 44)           0         ['reduction_concat_stem_1[0][0
#  n)                                                                 ]']
#
#  reduction_add_2_stem_2 (Ad  (None, 28, 28, 22)           0         ['reduction_left2_stem_2[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Av  (None, 28, 28, 22)           0         ['reduction_pad_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_2_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  reduction_left4_stem_2 (Av  (None, 28, 28, 22)           0         ['reduction_add_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 28, 28, 22)           88        ['separable_conv_2_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_right5_stem_2 (M  (None, 28, 28, 22)           0         ['reduction_pad_1_stem_2[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d_1 (ZeroPadd  (None, 57, 57, 44)           0         ['adjust_relu_1_0[0][0]']
#  ing2D)
#
#  reduction_add3_stem_2 (Add  (None, 28, 28, 22)           0         ['reduction_left3_stem_2[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_2[0][0]']
#
#  add_1 (Add)                 (None, 28, 28, 22)           0         ['reduction_add_2_stem_2[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_2[0][0]
#                                                                     ']
#
#  reduction_add4_stem_2 (Add  (None, 28, 28, 22)           0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_2[0][0]',
#                                                                      'reduction_right5_stem_2[0][0
#                                                                     ]']
#
#  cropping2d_1 (Cropping2D)   (None, 56, 56, 44)           0         ['zero_padding2d_1[0][0]']
#
#  reduction_concat_stem_2 (C  (None, 28, 28, 88)           0         ['reduction_add_2_stem_2[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_2[0][0]'
#                                                                     , 'add_1[0][0]',
#                                                                      'reduction_add4_stem_2[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_0 (Avera  (None, 28, 28, 44)           0         ['adjust_relu_1_0[0][0]']
#  gePooling2D)
#
#  adjust_avg_pool_2_0 (Avera  (None, 28, 28, 44)           0         ['cropping2d_1[0][0]']
#  gePooling2D)
#
#  adjust_conv_1_0 (Conv2D)    (None, 28, 28, 22)           968       ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)    (None, 28, 28, 22)           968       ['adjust_avg_pool_2_0[0][0]']
#
#  activation_22 (Activation)  (None, 28, 28, 88)           0         ['reduction_concat_stem_2[0][0
#                                                                     ]']
#
#  concatenate_1 (Concatenate  (None, 28, 28, 44)           0         ['adjust_conv_1_0[0][0]',
#  )                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)    (None, 28, 28, 44)           3872      ['activation_22[0][0]']
#
#  adjust_bn_0 (BatchNormaliz  (None, 28, 28, 44)           176       ['concatenate_1[0][0]']
#  ation)
#
#  normal_bn_1_0 (BatchNormal  (None, 28, 28, 44)           176       ['normal_conv_1_0[0][0]']
#  ization)
#
#  activation_23 (Activation)  (None, 28, 28, 44)           0         ['normal_bn_1_0[0][0]']
#
#  activation_25 (Activation)  (None, 28, 28, 44)           0         ['adjust_bn_0[0][0]']
#
#  activation_27 (Activation)  (None, 28, 28, 44)           0         ['adjust_bn_0[0][0]']
#
#  activation_29 (Activation)  (None, 28, 28, 44)           0         ['adjust_bn_0[0][0]']
#
#  activation_31 (Activation)  (None, 28, 28, 44)           0         ['normal_bn_1_0[0][0]']
#
#  separable_conv_1_normal_le  (None, 28, 28, 44)           3036      ['activation_23[0][0]']
#  ft1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 28, 28, 44)           2332      ['activation_25[0][0]']
#  ght1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 28, 28, 44)           3036      ['activation_27[0][0]']
#  ft2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 28, 28, 44)           2332      ['activation_29[0][0]']
#  ght2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 28, 28, 44)           2332      ['activation_31[0][0]']
#  ft5_0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 28, 28, 44)           176       ['separable_conv_1_normal_left
#  _left1_0 (BatchNormalizati                                         1_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 28, 28, 44)           176       ['separable_conv_1_normal_righ
#  _right1_0 (BatchNormalizat                                         t1_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 28, 28, 44)           176       ['separable_conv_1_normal_left
#  _left2_0 (BatchNormalizati                                         2_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 28, 28, 44)           176       ['separable_conv_1_normal_righ
#  _right2_0 (BatchNormalizat                                         t2_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 28, 28, 44)           176       ['separable_conv_1_normal_left
#  _left5_0 (BatchNormalizati                                         5_0[0][0]']
#  on)
#
#  activation_24 (Activation)  (None, 28, 28, 44)           0         ['separable_conv_1_bn_normal_l
#                                                                     eft1_0[0][0]']
#
#  activation_26 (Activation)  (None, 28, 28, 44)           0         ['separable_conv_1_bn_normal_r
#                                                                     ight1_0[0][0]']
#
#  activation_28 (Activation)  (None, 28, 28, 44)           0         ['separable_conv_1_bn_normal_l
#                                                                     eft2_0[0][0]']
#
#  activation_30 (Activation)  (None, 28, 28, 44)           0         ['separable_conv_1_bn_normal_r
#                                                                     ight2_0[0][0]']
#
#  activation_32 (Activation)  (None, 28, 28, 44)           0         ['separable_conv_1_bn_normal_l
#                                                                     eft5_0[0][0]']
# ...
#
#  normal_conv_1_12 (Conv2D)   (None, 7, 7, 176)            185856    ['activation_176[0][0]']
#
#  adjust_bn_12 (BatchNormali  (None, 7, 7, 176)            704       ['adjust_conv_projection_12[0]
#  zation)                                                            [0]']
#
#  normal_bn_1_12 (BatchNorma  (None, 7, 7, 176)            704       ['normal_conv_1_12[0][0]']
#  lization)
#
#  activation_177 (Activation  (None, 7, 7, 176)            0         ['normal_bn_1_12[0][0]']
#  )
#
#  activation_179 (Activation  (None, 7, 7, 176)            0         ['adjust_bn_12[0][0]']
#  )
#
#  activation_181 (Activation  (None, 7, 7, 176)            0         ['adjust_bn_12[0][0]']
#  )
#
#  activation_183 (Activation  (None, 7, 7, 176)            0         ['adjust_bn_12[0][0]']
#  )
#
#  activation_185 (Activation  (None, 7, 7, 176)            0         ['normal_bn_1_12[0][0]']
#  )
#
#  separable_conv_1_normal_le  (None, 7, 7, 176)            35376     ['activation_177[0][0]']
#  ft1_12 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 7, 7, 176)            32560     ['activation_179[0][0]']
#  ght1_12 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 7, 7, 176)            35376     ['activation_181[0][0]']
#  ft2_12 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 7, 7, 176)            32560     ['activation_183[0][0]']
#  ght2_12 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 7, 7, 176)            32560     ['activation_185[0][0]']
#  ft5_12 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_1_normal_left
#  _left1_12 (BatchNormalizat                                         1_12[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_1_normal_righ
#  _right1_12 (BatchNormaliza                                         t1_12[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_1_normal_left
#  _left2_12 (BatchNormalizat                                         2_12[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_1_normal_righ
#  _right2_12 (BatchNormaliza                                         t2_12[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_1_normal_left
#  _left5_12 (BatchNormalizat                                         5_12[0][0]']
#  ion)
#
#  activation_178 (Activation  (None, 7, 7, 176)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft1_12[0][0]']
#
#  activation_180 (Activation  (None, 7, 7, 176)            0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight1_12[0][0]']
#
#  activation_182 (Activation  (None, 7, 7, 176)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft2_12[0][0]']
#
#  activation_184 (Activation  (None, 7, 7, 176)            0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight2_12[0][0]']
#
#  activation_186 (Activation  (None, 7, 7, 176)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft5_12[0][0]']
#
#  separable_conv_2_normal_le  (None, 7, 7, 176)            35376     ['activation_178[0][0]']
#  ft1_12 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 7, 7, 176)            32560     ['activation_180[0][0]']
#  ght1_12 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 7, 7, 176)            35376     ['activation_182[0][0]']
#  ft2_12 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 7, 7, 176)            32560     ['activation_184[0][0]']
#  ght2_12 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 7, 7, 176)            32560     ['activation_186[0][0]']
#  ft5_12 (SeparableConv2D)
#
#  separable_conv_2_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_2_normal_left
#  _left1_12 (BatchNormalizat                                         1_12[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_2_normal_righ
#  _right1_12 (BatchNormaliza                                         t1_12[0][0]']
#  tion)
#
#  separable_conv_2_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_2_normal_left
#  _left2_12 (BatchNormalizat                                         2_12[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_2_normal_righ
#  _right2_12 (BatchNormaliza                                         t2_12[0][0]']
#  tion)
#
#  normal_left3_12 (AveragePo  (None, 7, 7, 176)            0         ['normal_bn_1_12[0][0]']
#  oling2D)
#
#  normal_left4_12 (AveragePo  (None, 7, 7, 176)            0         ['adjust_bn_12[0][0]']
#  oling2D)
#
#  normal_right4_12 (AverageP  (None, 7, 7, 176)            0         ['adjust_bn_12[0][0]']
#  ooling2D)
#
#  separable_conv_2_bn_normal  (None, 7, 7, 176)            704       ['separable_conv_2_normal_left
#  _left5_12 (BatchNormalizat                                         5_12[0][0]']
#  ion)
#
#  normal_add_1_12 (Add)       (None, 7, 7, 176)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft1_12[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight1_12[0][0]']
#
#  normal_add_2_12 (Add)       (None, 7, 7, 176)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft2_12[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight2_12[0][0]']
#
#  normal_add_3_12 (Add)       (None, 7, 7, 176)            0         ['normal_left3_12[0][0]',
#                                                                      'adjust_bn_12[0][0]']
#
#  normal_add_4_12 (Add)       (None, 7, 7, 176)            0         ['normal_left4_12[0][0]',
#                                                                      'normal_right4_12[0][0]']
#
#  normal_add_5_12 (Add)       (None, 7, 7, 176)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft5_12[0][0]',
#                                                                      'normal_bn_1_12[0][0]']
#
#  normal_concat_12 (Concaten  (None, 7, 7, 1056)           0         ['adjust_bn_12[0][0]',
#  ate)                                                                'normal_add_1_12[0][0]',
#                                                                      'normal_add_2_12[0][0]',
#                                                                      'normal_add_3_12[0][0]',
#                                                                      'normal_add_4_12[0][0]',
#                                                                      'normal_add_5_12[0][0]']
#
#  activation_187 (Activation  (None, 7, 7, 1056)           0         ['normal_concat_12[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 1056)                 0         ['activation_187[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                   67648     ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_1 (Dense)             (None, 64)                   4160      ['dense[0][0]']
#
#  dense_2 (Dense)             (None, 4)                    260       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 4341784 (16.56 MB)
# Trainable params: 72068 (281.52 KB)
# Non-trainable params: 4269716 (16.29 MB)
# __________________________________________________________________________________________________

# %%
import sklearn
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, precision_score, accuracy_score, f1_score, recall_score

# %%
def fit_model_and_save_logs(model, name:str, train_, valid_):
    # Initialize metrics list
    metrics = []

    # Extract true labels from the validation dataset
    true_values = [y for x, y in valid_.unbatch()]

    # Define callbacks
    es_cb = EarlyStopping(
        monitor='val_accuracy',
        patience=20,
        mode='auto',
        restore_best_weights=True
    )
    lr_cb = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=0.0001,
        verbose=1
    )
    checkpoint_cb = ModelCheckpoint(
        filepath=f"{name}_best_model.h5",
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
    csv_log = keras.callbacks.CSVLogger(
        filename = f"{name}_logs.csv",
        separator = ","
    )

    model.fit(
        train_,
        validation_data = valid_,
        callbacks = [es_cb, lr_cb, csv_log, checkpoint_cb],
        verbose = 2,
        epochs = NUM_EPOCHS,
        # Added inverse class weight
        class_weight=weight_dict
    )

    # Convert history to a DataFrame for easier plotting
    history_df = pd.DataFrame(model.history.history)
    # Plot accuracy and loss
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (17,6), sharey = False)
    history_df[["accuracy", "val_accuracy"]].plot(ax = ax[0], title = "Accuracy vs Validation Accuracy", lw = 2)
    history_df[["loss", "val_loss"]].plot(ax = ax[1], title = "Loss vs Validation Loss", lw = 1.7)
    plt.savefig(f"{name}_train_val.png")

    # Predict on validation data
    preds = model.predict(valid_, verbose = 2)
    preds = np.argmax(preds, axis  = 1)

    # Calculate metrics
    accuracy_ = accuracy_score(true_values, preds) * 100
    precision_ = precision_score(true_values, preds, average="weighted") * 100
    f1_ = f1_score(true_values, preds, average="weighted") * 100
    recall_ = recall_score(true_values, preds, average="weighted") * 100
    metrics.extend([accuracy_, precision_, f1_, recall_])

    # Classification report
    cr = classification_report(true_values, preds, output_dict = True)
    cr = pd.DataFrame(cr)
    cr.columns = ['coccidiosis', 'healthy', 'newcastle disease', 'salmo', 'accuracy', 'macro avg', 'weighted avg']
    cr = cr.T
    cr.to_csv(f"{name}_classification_report.csv", index = 1)

    fig, ax = plt.subplots(1,1,figsize = (10,10))
    ConfusionMatrixDisplay.from_predictions(true_values, preds, cmap = "Blues", display_labels = ['coccidiosis', 'healthy', 'newcastle disease', 'salmo'], ax = ax)
    plt.title(f"{name} Confusion Matrix")
    plt.savefig(f"{name}_confusion_matrix.jpg")

    metric_dataframe = pd.DataFrame(
            data = {"metrics": ["Accuracy", "Precision", "F1_Score", "Recall"],
                    "score": metrics,
                    "name": [f"{name}", f"{name}", f"{name}", f"{name}"]}
    )
    return metric_dataframe

# %%
nnm_metric_df_1 = fit_model_and_save_logs(nasnetmobile_model, "nasnetmobile", train_batch, valid_batch)
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.81851, saving model to nasnetmobile_best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 281/281 - 41s - loss: 0.8731 - accuracy: 0.6973 - val_loss: 0.5216 - val_accuracy: 0.8185 - lr: 1.0000e-04 - 41s/epoch - 146ms/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.81851 to 0.85943, saving model to nasnetmobile_best_model.h5
# 281/281 - 15s - loss: 0.4337 - accuracy: 0.8516 - val_loss: 0.3930 - val_accuracy: 0.8594 - lr: 1.0000e-04 - 15s/epoch - 55ms/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.85943 to 0.86833, saving model to nasnetmobile_best_model.h5
# 281/281 - 15s - loss: 0.3514 - accuracy: 0.8801 - val_loss: 0.3532 - val_accuracy: 0.8683 - lr: 1.0000e-04 - 15s/epoch - 55ms/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.86833 to 0.87589, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.3127 - accuracy: 0.8939 - val_loss: 0.3323 - val_accuracy: 0.8759 - lr: 1.0000e-04 - 16s/epoch - 56ms/step
# Epoch 5/50
#
# Epoch 5: val_accuracy improved from 0.87589 to 0.88167, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.2866 - accuracy: 0.9031 - val_loss: 0.3184 - val_accuracy: 0.8817 - lr: 1.0000e-04 - 16s/epoch - 56ms/step
# Epoch 6/50
#
# Epoch 6: val_accuracy improved from 0.88167 to 0.88612, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.2668 - accuracy: 0.9100 - val_loss: 0.3083 - val_accuracy: 0.8861 - lr: 1.0000e-04 - 16s/epoch - 56ms/step
# Epoch 7/50
#
# Epoch 7: val_accuracy improved from 0.88612 to 0.88968, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.2502 - accuracy: 0.9168 - val_loss: 0.3008 - val_accuracy: 0.8897 - lr: 1.0000e-04 - 16s/epoch - 56ms/step
# Epoch 8/50
#
# Epoch 8: val_accuracy improved from 0.88968 to 0.89190, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.2360 - accuracy: 0.9210 - val_loss: 0.2960 - val_accuracy: 0.8919 - lr: 1.0000e-04 - 16s/epoch - 57ms/step
# Epoch 9/50
#
# Epoch 9: val_accuracy improved from 0.89190 to 0.89235, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.2234 - accuracy: 0.9262 - val_loss: 0.2924 - val_accuracy: 0.8923 - lr: 1.0000e-04 - 16s/epoch - 56ms/step
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.89235
# 281/281 - 14s - loss: 0.2119 - accuracy: 0.9308 - val_loss: 0.2899 - val_accuracy: 0.8919 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.89235
# 281/281 - 14s - loss: 0.2013 - accuracy: 0.9351 - val_loss: 0.2883 - val_accuracy: 0.8910 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 12/50
#
# Epoch 12: val_accuracy improved from 0.89235 to 0.89457, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.1914 - accuracy: 0.9384 - val_loss: 0.2865 - val_accuracy: 0.8946 - lr: 1.0000e-04 - 16s/epoch - 56ms/step
# Epoch 13/50
#
# Epoch 13: val_accuracy improved from 0.89457 to 0.89680, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.1823 - accuracy: 0.9412 - val_loss: 0.2855 - val_accuracy: 0.8968 - lr: 1.0000e-04 - 16s/epoch - 57ms/step
# Epoch 14/50
#
# Epoch 14: val_accuracy did not improve from 0.89680
# 281/281 - 15s - loss: 0.1737 - accuracy: 0.9467 - val_loss: 0.2857 - val_accuracy: 0.8959 - lr: 1.0000e-04 - 15s/epoch - 53ms/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.89680
# 281/281 - 15s - loss: 0.1656 - accuracy: 0.9494 - val_loss: 0.2860 - val_accuracy: 0.8968 - lr: 1.0000e-04 - 15s/epoch - 52ms/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.89680
# 281/281 - 15s - loss: 0.1579 - accuracy: 0.9528 - val_loss: 0.2867 - val_accuracy: 0.8968 - lr: 1.0000e-04 - 15s/epoch - 52ms/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.89680
# 281/281 - 15s - loss: 0.1506 - accuracy: 0.9550 - val_loss: 0.2879 - val_accuracy: 0.8968 - lr: 1.0000e-04 - 15s/epoch - 53ms/step
# Epoch 18/50
#
# Epoch 18: val_accuracy improved from 0.89680 to 0.89769, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.1436 - accuracy: 0.9573 - val_loss: 0.2891 - val_accuracy: 0.8977 - lr: 1.0000e-04 - 16s/epoch - 57ms/step
# Epoch 19/50
#
# Epoch 19: val_accuracy improved from 0.89769 to 0.89858, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.1370 - accuracy: 0.9597 - val_loss: 0.2907 - val_accuracy: 0.8986 - lr: 1.0000e-04 - 16s/epoch - 57ms/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.89858
# 281/281 - 15s - loss: 0.1306 - accuracy: 0.9623 - val_loss: 0.2919 - val_accuracy: 0.8981 - lr: 1.0000e-04 - 15s/epoch - 52ms/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.89858
# 281/281 - 15s - loss: 0.1244 - accuracy: 0.9644 - val_loss: 0.2937 - val_accuracy: 0.8981 - lr: 1.0000e-04 - 15s/epoch - 53ms/step
# Epoch 22/50
#
# Epoch 22: val_accuracy improved from 0.89858 to 0.89947, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.1185 - accuracy: 0.9662 - val_loss: 0.2950 - val_accuracy: 0.8995 - lr: 1.0000e-04 - 16s/epoch - 58ms/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.89947
# 281/281 - 15s - loss: 0.1129 - accuracy: 0.9680 - val_loss: 0.2961 - val_accuracy: 0.8990 - lr: 1.0000e-04 - 15s/epoch - 53ms/step
# Epoch 24/50
#
# Epoch 24: val_accuracy improved from 0.89947 to 0.89991, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.1074 - accuracy: 0.9694 - val_loss: 0.2982 - val_accuracy: 0.8999 - lr: 1.0000e-04 - 16s/epoch - 57ms/step
# Epoch 25/50
#
# Epoch 25: val_accuracy did not improve from 0.89991
# 281/281 - 15s - loss: 0.1020 - accuracy: 0.9716 - val_loss: 0.3004 - val_accuracy: 0.8990 - lr: 1.0000e-04 - 15s/epoch - 53ms/step
# Epoch 26/50
#
# Epoch 26: val_accuracy did not improve from 0.89991
# 281/281 - 15s - loss: 0.0969 - accuracy: 0.9736 - val_loss: 0.3021 - val_accuracy: 0.8990 - lr: 1.0000e-04 - 15s/epoch - 53ms/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.89991
# 281/281 - 15s - loss: 0.0920 - accuracy: 0.9754 - val_loss: 0.3050 - val_accuracy: 0.8995 - lr: 1.0000e-04 - 15s/epoch - 52ms/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.89991
# 281/281 - 15s - loss: 0.0873 - accuracy: 0.9769 - val_loss: 0.3083 - val_accuracy: 0.8999 - lr: 1.0000e-04 - 15s/epoch - 53ms/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.89991
# 281/281 - 15s - loss: 0.0828 - accuracy: 0.9786 - val_loss: 0.3108 - val_accuracy: 0.8995 - lr: 1.0000e-04 - 15s/epoch - 52ms/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.89991
# 281/281 - 14s - loss: 0.0784 - accuracy: 0.9804 - val_loss: 0.3126 - val_accuracy: 0.8999 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.89991
# 281/281 - 14s - loss: 0.0741 - accuracy: 0.9827 - val_loss: 0.3171 - val_accuracy: 0.8990 - lr: 1.0000e-04 - 14s/epoch - 52ms/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.89991
# 281/281 - 14s - loss: 0.0700 - accuracy: 0.9847 - val_loss: 0.3191 - val_accuracy: 0.8990 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 33/50
#
# Epoch 33: val_accuracy improved from 0.89991 to 0.90080, saving model to nasnetmobile_best_model.h5
# 281/281 - 16s - loss: 0.0661 - accuracy: 0.9853 - val_loss: 0.3232 - val_accuracy: 0.9008 - lr: 1.0000e-04 - 16s/epoch - 56ms/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0624 - accuracy: 0.9863 - val_loss: 0.3279 - val_accuracy: 0.8990 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0587 - accuracy: 0.9873 - val_loss: 0.3322 - val_accuracy: 0.8990 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0554 - accuracy: 0.9885 - val_loss: 0.3367 - val_accuracy: 0.8995 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0519 - accuracy: 0.9900 - val_loss: 0.3417 - val_accuracy: 0.9004 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0488 - accuracy: 0.9907 - val_loss: 0.3458 - val_accuracy: 0.8999 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0457 - accuracy: 0.9912 - val_loss: 0.3506 - val_accuracy: 0.8977 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0427 - accuracy: 0.9928 - val_loss: 0.3564 - val_accuracy: 0.8964 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0400 - accuracy: 0.9940 - val_loss: 0.3623 - val_accuracy: 0.8968 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0372 - accuracy: 0.9948 - val_loss: 0.3684 - val_accuracy: 0.8968 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0348 - accuracy: 0.9950 - val_loss: 0.3735 - val_accuracy: 0.8977 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0322 - accuracy: 0.9960 - val_loss: 0.3805 - val_accuracy: 0.8972 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0300 - accuracy: 0.9964 - val_loss: 0.3847 - val_accuracy: 0.8972 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0276 - accuracy: 0.9967 - val_loss: 0.3925 - val_accuracy: 0.8972 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 47/50
#
# Epoch 47: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0256 - accuracy: 0.9970 - val_loss: 0.4015 - val_accuracy: 0.8955 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 48/50
#
# Epoch 48: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0236 - accuracy: 0.9976 - val_loss: 0.4073 - val_accuracy: 0.8941 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 49/50
#
# Epoch 49: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0219 - accuracy: 0.9980 - val_loss: 0.4146 - val_accuracy: 0.8937 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# Epoch 50/50
#
# Epoch 50: val_accuracy did not improve from 0.90080
# 281/281 - 14s - loss: 0.0200 - accuracy: 0.9984 - val_loss: 0.4224 - val_accuracy: 0.8941 - lr: 1.0000e-04 - 14s/epoch - 51ms/step
# 71/71 - 7s - 7s/epoch - 101ms/step

# %%
mkdir output

# %%
cp -r './output' '/content/drive/MyDrive/Colab Notebooks/pravin_thesis/2_Image_classification/6_NasNetMobile/1_output_50_epoch'

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import keras_cv

# # Define the custom objects
custom_objects = {
    'AdamW': AdamW
}

# Load the saved model with custom objects
model = load_model('nasnetmobile_best_model.h5',
                   custom_objects=custom_objects
                   )

# %%
# Load and preprocess the sample image
image_class = 'salmo'
img_path = f'./dataset/{image_class}/{image_class}.99.jpg'
img = image.load_img(img_path, target_size=IMAGE_SIZE)
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
img_array = img_array / 255.0  # Normalize the image if your model expects normalized images

# Make a prediction
predictions = model.predict(img_array)

# Interpret the prediction (this depends on your model's output format)
predicted_class = np.argmax(predictions, axis=1)
print(f"Predicted class: {predicted_class}")
# Out:
# 1/1 [==============================] - 0s 42ms/step
# Predicted class: [3]
