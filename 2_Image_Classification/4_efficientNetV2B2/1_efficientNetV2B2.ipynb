# %%
# # Google Colab Specific commands
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # # Example: Unzip into the current working directory - since i have a zip in my drive and i want to unzip into my colab env for faster access
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/pravin_thesis/0_dataset/11_balanced_class_subfolder_no_label.zip" -d '/content/dataset/'

# %%
# !pip install keras_cv rasterio
# Out:
# Collecting keras_cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 9.1 MB/s eta 0:00:00
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 70.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_cv) (24.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras_cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras_cv) (2024.5.15)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras_cv) (4.9.6)
# Collecting keras-core (from keras_cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 67.8 MB/s eta 0:00:00
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras_cv) (0.2.5)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.7.4)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (4.66.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (13.7.1)
# Collecting namex (from keras-core->keras_cv)
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (0.1.8)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (3.20.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (14.0.2)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.1.5)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.4.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.14.1)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.5.1)
# Requirement already satisfied: etils[enp,epath,epy,etree]>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.7.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras_cv) (4.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras_cv) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras_cv) (6.4.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras_cv) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (2.0.7)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (2.16.1)
# Requirement already satisfied: docstring-parser~=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras_cv) (0.16)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)
# Installing collected packages: namex, snuggs, affine, rasterio, keras-core, keras_cv
# Successfully installed affine-2.4.0 keras-core-0.1.7 keras_cv-0.9.0 namex-0.0.8 rasterio-1.3.10 snuggs-1.4.7

# %%
# Standard Library Imports
import os
import random
import shutil
import warnings
# Data Analysis and Manipulation
import pandas as pd
import numpy as np
# Image Processing
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import rasterio
from PIL import Image
import PIL
# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
# Machine Learning and Deep Learning
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.utils import image_dataset_from_directory
from keras.optimizers import AdamW
import keras_cv
keras.mixed_precision.set_global_policy("mixed_float16")
# Progress Bars
import tqdm
from tqdm.auto import trange, tqdm
# Evaluation Metrics
import sklearn
from sklearn.metrics import precision_score, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
# Out:
# Using TensorFlow backend

# %%
IMAGE_SIZE = (260,260) #For EfficentNetV2B2
BATCH_SIZE = 32
COLOR_MODE = "rgb"
SHUFFLE = True
TRAIN_PATH = "/content/dataset/"
SEED = 4224
AUTOTUNE = tf.data.experimental.AUTOTUNE
NUM_CLASSES = 4
NUM_EPOCHS = 50
INITIAL_LEARNING_RATE = 0.0001

# %%
IMAGE_SIZE
# Out:
# (260, 260)

# %%
def load_batches(imgsz: tuple, bsz: int, clr: str, shuffle: bool, path_: str, seed: int):
    try:
        batch_1, batch_2 = image_dataset_from_directory(
            image_size=imgsz,
            directory=path_,
            color_mode=clr,
            shuffle=shuffle,
            validation_split=0.2,
            subset="both",
            seed=seed,
            labels="inferred",
            batch_size=bsz,
            class_names=None,
            interpolation="bilinear",
            crop_to_aspect_ratio=True
        )
        return batch_1, batch_2
    except ValueError as e:
        print(f"Error loading data from directory {path_}: {str(e)}")
        return None, None

train_batch, valid_batch = load_batches(imgsz=IMAGE_SIZE, bsz=BATCH_SIZE, clr=COLOR_MODE, shuffle=SHUFFLE, path_=TRAIN_PATH, seed=SEED)
if train_batch is None:
    print("Failed to load training batch. Check directory and file formats.")
# Out:
# Found 11240 files belonging to 4 classes.
# Using 8992 files for training.
# Using 2248 files for validation.

# %%
train_batch.class_names
# Out:
# ['cocci', 'healthy', 'ncd', 'salmo']

# %%
def rescale_imgs(img_, lbl_):
    img_ = tf.cast(img_, tf.float32)
    return img_/255.0, lbl_

train_batch = train_batch.map(rescale_imgs, num_parallel_calls = tf.data.AUTOTUNE)
valid_batch = valid_batch.map(rescale_imgs, num_parallel_calls = tf.data.AUTOTUNE)

# %%
def augment_img(img_, lbl_):
    image = tf.image.random_flip_left_right(img_)
    image = tf.image.central_crop(image, 0.85)
    image = tf.image.resize(image, IMAGE_SIZE)
    image = tf.image.random_brightness(image, 0.2)
    image = tf.image.random_contrast(image, 0.5, 2.0)
    return tf.cast(image, tf.float32), lbl_

train_batch = train_batch.map(augment_img, tf.data.AUTOTUNE)
train_batch = train_batch.cache().prefetch(buffer_size = tf.data.AUTOTUNE)
valid_batch = valid_batch.cache().prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
len(valid_batch) * 32
# Out:
# 2272

# %%
def val_batch_class_distribution(valid_batch):
    images = list()
    labels = list()

    for img, lbl in valid_batch.unbatch():
        images.append(img)
        if lbl == 0:
            labels.append("Coccidiosis")
        elif lbl == 1:
            labels.append("Healthy")
        elif lbl == 2:
            labels.append("Newcastle Disease")
        else:
            labels.append("Salmo")
    images = np.array(images)
    labels = np.array(labels)

    print(f'Coccidiosis Percentage: {np.mean(labels == "Coccidiosis")}')
    print(f'Healthy Percentage: {np.mean(labels == "Healthy")}')
    print(f'Newcastle Disease Percentage: {np.mean(labels == "Newcastle Disease")}')
    print(f'Salmo Percentage: {np.mean(labels == "Salmo")}')
    return labels

labels_ = val_batch_class_distribution(valid_batch)
# Out:
# Coccidiosis Percentage: 0.2611209964412811
# Healthy Percentage: 0.24332740213523132
# Newcastle Disease Percentage: 0.2557829181494662
# Salmo Percentage: 0.23976868327402134

# %%
weights_ = class_weight.compute_class_weight("balanced", classes = ['coccidiosis', 'healthy', 'newcastle disease', 'salmo'], y = [i.lower() for i in labels_])
weight_dict = {}
for i, j in enumerate(weights_):
    weight_dict[i] = j
weight_dict
# Out:
# {0: 0.9574105621805792,
#  1: 1.0274223034734917,
#  2: 0.9773913043478261,
#  3: 1.0426716141001855}

# %%
def create_efficient_model():
  # LINK: https://keras.io/api/keras_cv/models/backbones/efficientnet_v2/#efficientnetv2b2backbone-class
    backbone = keras_cv.models.EfficientNetV2Backbone.from_preset(
        # Use efficientnetv2_b2_imagenet or efficientnetv2_b2
        "efficientnetv2_b2_imagenet",
        activation="relu",
        # the suitable input shape: https://www.kaggle.com/models/google/efficientnet-v2
        # 260,260 is recommneded
        input_shape=(260, 260, 3),
        include_rescaling = False,
        load_weights = True
    )
    # TODO: Comment the below line if performing bad.
    # backbone.trainable = False

    model = keras_cv.models.ImageClassifier(
        backbone=backbone,
        num_classes=NUM_CLASSES,
        activation = "softmax",
        name = "KerasCV_efficientnet"
    )
    # TODO: Uncomment the below line if performing bad.
    model.trainable = True

    initial_learning_rate = INITIAL_LEARNING_RATE
    optimizer = keras.optimizers.AdamW(learning_rate = initial_learning_rate)

    model.compile(optimizer = optimizer,
                  loss = keras.losses.SparseCategoricalCrossentropy(),
                  metrics = ["accuracy"])
    return model

# %%
efficient_model = create_efficient_model()
# Out:
# Downloading from https://www.kaggle.com/api/v1/models/keras/efficientnetv2/keras/efficientnetv2_b2_imagenet/2/download/config.json...
# 100%|██████████| 1.79k/1.79k [00:00<00:00, 2.77MB/s]
# Downloading from https://www.kaggle.com/api/v1/models/keras/efficientnetv2/keras/efficientnetv2_b2_imagenet/2/download/model.weights.h5...
# 100%|██████████| 34.2M/34.2M [00:03<00:00, 11.4MB/s]
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/backbones/backbone.py:44: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   return id(getattr(self, attr)) not in self._functional_layer_ids

# %%
keras.utils.plot_model(efficient_model, to_file = "efficientnetv2B2_model_architecture.png", show_shapes = True)

# %%
efficient_model.summary()
# Out:
# Model: "KerasCV_efficientnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 260, 260, 3)]     0
#
#  efficient_net_v2b2_backbon  (None, 9, 9, 1408)        8769374
#  e (EfficientNetV2Backbone)
#
#  avg_pool (GlobalAveragePoo  (None, 1408)              0
#  ling2D)
#
#  predictions (Dense)         (None, 4)                 5636
#
# =================================================================
# Total params: 8775010 (33.47 MB)
# Trainable params: 8692722 (33.16 MB)
# Non-trainable params: 82288 (321.44 KB)
# _________________________________________________________________

# %%
import sklearn
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, precision_score, accuracy_score, f1_score, recall_score

# %%
def fit_model_and_save_logs(model, name:str, train_, valid_):
    # Initialize metrics list
    metrics = []

    # Extract true labels from the validation dataset
    true_values = [y for x, y in valid_.unbatch()]

    # Define callbacks
    es_cb = EarlyStopping(
        monitor='val_accuracy',
        patience=20,
        mode='auto',
        restore_best_weights=True
    )
    lr_cb = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=5,
        min_lr=0.0001,
        verbose=1
    )
    checkpoint_cb = ModelCheckpoint(
        filepath=f"{name}_best_model.h5",
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
    csv_log = keras.callbacks.CSVLogger(
        filename = f"{name}_logs.csv",
        separator = ","
    )

    model.fit(
        train_,
        validation_data = valid_,
        callbacks = [es_cb, lr_cb, csv_log, checkpoint_cb],
        verbose = 2,
        epochs = NUM_EPOCHS,
        # Added inverse class weight
        class_weight=weight_dict
    )

    # Convert history to a DataFrame for easier plotting
    history_df = pd.DataFrame(model.history.history)
    # Plot accuracy and loss
    fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (17,6), sharey = False)
    history_df[["accuracy", "val_accuracy"]].plot(ax = ax[0], title = "Accuracy vs Validation Accuracy", lw = 2)
    history_df[["loss", "val_loss"]].plot(ax = ax[1], title = "Loss vs Validation Loss", lw = 1.7)
    plt.savefig(f"{name}_train_val.png")

    # Predict on validation data
    preds = model.predict(valid_, verbose = 2)
    preds = np.argmax(preds, axis  = 1)

    # Calculate metrics
    accuracy_ = accuracy_score(true_values, preds) * 100
    precision_ = precision_score(true_values, preds, average="weighted") * 100
    f1_ = f1_score(true_values, preds, average="weighted") * 100
    recall_ = recall_score(true_values, preds, average="weighted") * 100
    metrics.extend([accuracy_, precision_, f1_, recall_])

    # Classification report
    cr = classification_report(true_values, preds, output_dict = True)
    cr = pd.DataFrame(cr)
    cr.columns = ['coccidiosis', 'healthy', 'newcastle disease', 'salmo', 'accuracy', 'macro avg', 'weighted avg']
    cr = cr.T
    cr.to_csv(f"{name}_classification_report.csv", index = 1)

    fig, ax = plt.subplots(1,1,figsize = (10,10))
    ConfusionMatrixDisplay.from_predictions(true_values, preds, cmap = "Blues", display_labels = ['coccidiosis', 'healthy', 'newcastle disease', 'salmo'], ax = ax)
    plt.title(f"{name} Confusion Matrix")
    plt.savefig(f"{name}_confusion_matrix.jpg")

    metric_dataframe = pd.DataFrame(
            data = {"metrics": ["Accuracy", "Precision", "F1_Score", "Recall"],
                    "score": metrics,
                    "name": [f"{name}", f"{name}", f"{name}", f"{name}"]}
    )
    return metric_dataframe

# %%
en_metric_df_V2_B2_imagenet = fit_model_and_save_logs(efficient_model, "efficientnetV2B2", train_batch, valid_batch)
# with imagenet weights
# Out:
# Epoch 1/50
#
# Epoch 1: val_accuracy improved from -inf to 0.92171, saving model to efficientnetV2B2_best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 281/281 - 131s - loss: 0.6180 - accuracy: 0.7845 - val_loss: 0.2266 - val_accuracy: 0.9217 - lr: 1.0000e-04 - 131s/epoch - 467ms/step
# Epoch 2/50
#
# Epoch 2: val_accuracy improved from 0.92171 to 0.94528, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 52s - loss: 0.1883 - accuracy: 0.9391 - val_loss: 0.1523 - val_accuracy: 0.9453 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 3/50
#
# Epoch 3: val_accuracy improved from 0.94528 to 0.94884, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 52s - loss: 0.1192 - accuracy: 0.9625 - val_loss: 0.1402 - val_accuracy: 0.9488 - lr: 1.0000e-04 - 52s/epoch - 186ms/step
# Epoch 4/50
#
# Epoch 4: val_accuracy improved from 0.94884 to 0.95907, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 52s - loss: 0.0810 - accuracy: 0.9759 - val_loss: 0.1249 - val_accuracy: 0.9591 - lr: 1.0000e-04 - 52s/epoch - 187ms/step
# Epoch 5/50
#
# Epoch 5: val_accuracy did not improve from 0.95907
# 281/281 - 52s - loss: 0.0571 - accuracy: 0.9829 - val_loss: 0.1424 - val_accuracy: 0.9520 - lr: 1.0000e-04 - 52s/epoch - 183ms/step
# Epoch 6/50
#
# Epoch 6: val_accuracy did not improve from 0.95907
# 281/281 - 52s - loss: 0.0424 - accuracy: 0.9882 - val_loss: 0.1671 - val_accuracy: 0.9462 - lr: 1.0000e-04 - 52s/epoch - 184ms/step
# Epoch 7/50
#
# Epoch 7: val_accuracy did not improve from 0.95907
# 281/281 - 52s - loss: 0.0373 - accuracy: 0.9899 - val_loss: 0.1496 - val_accuracy: 0.9520 - lr: 1.0000e-04 - 52s/epoch - 184ms/step
# Epoch 8/50
#
# Epoch 8: val_accuracy improved from 0.95907 to 0.96174, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 53s - loss: 0.0290 - accuracy: 0.9919 - val_loss: 0.1392 - val_accuracy: 0.9617 - lr: 1.0000e-04 - 53s/epoch - 189ms/step
# Epoch 9/50
#
# Epoch 9: val_accuracy improved from 0.96174 to 0.96397, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 53s - loss: 0.0241 - accuracy: 0.9933 - val_loss: 0.1358 - val_accuracy: 0.9640 - lr: 1.0000e-04 - 53s/epoch - 189ms/step
# Epoch 10/50
#
# Epoch 10: val_accuracy did not improve from 0.96397
# 281/281 - 52s - loss: 0.0227 - accuracy: 0.9937 - val_loss: 0.1356 - val_accuracy: 0.9631 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 11/50
#
# Epoch 11: val_accuracy did not improve from 0.96397
# 281/281 - 52s - loss: 0.0175 - accuracy: 0.9952 - val_loss: 0.1431 - val_accuracy: 0.9631 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 12/50
#
# Epoch 12: val_accuracy did not improve from 0.96397
# 281/281 - 52s - loss: 0.0175 - accuracy: 0.9951 - val_loss: 0.1459 - val_accuracy: 0.9600 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 13/50
#
# Epoch 13: val_accuracy did not improve from 0.96397
# 281/281 - 52s - loss: 0.0142 - accuracy: 0.9958 - val_loss: 0.1300 - val_accuracy: 0.9640 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 14/50
#
# Epoch 14: val_accuracy improved from 0.96397 to 0.96664, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 53s - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.1304 - val_accuracy: 0.9666 - lr: 1.0000e-04 - 53s/epoch - 189ms/step
# Epoch 15/50
#
# Epoch 15: val_accuracy did not improve from 0.96664
# 281/281 - 52s - loss: 0.0111 - accuracy: 0.9972 - val_loss: 0.2451 - val_accuracy: 0.9444 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 16/50
#
# Epoch 16: val_accuracy did not improve from 0.96664
# 281/281 - 52s - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.1701 - val_accuracy: 0.9617 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 17/50
#
# Epoch 17: val_accuracy did not improve from 0.96664
# 281/281 - 52s - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.1383 - val_accuracy: 0.9644 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 18/50
#
# Epoch 18: val_accuracy did not improve from 0.96664
# 281/281 - 52s - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.1741 - val_accuracy: 0.9577 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 19/50
#
# Epoch 19: val_accuracy did not improve from 0.96664
# 281/281 - 52s - loss: 0.0087 - accuracy: 0.9978 - val_loss: 0.1606 - val_accuracy: 0.9600 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 20/50
#
# Epoch 20: val_accuracy did not improve from 0.96664
# 281/281 - 52s - loss: 0.0081 - accuracy: 0.9978 - val_loss: 0.1636 - val_accuracy: 0.9600 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 21/50
#
# Epoch 21: val_accuracy did not improve from 0.96664
# 281/281 - 52s - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.3002 - val_accuracy: 0.9457 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 22/50
#
# Epoch 22: val_accuracy improved from 0.96664 to 0.96708, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 53s - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.1826 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 53s/epoch - 188ms/step
# Epoch 23/50
#
# Epoch 23: val_accuracy did not improve from 0.96708
# 281/281 - 52s - loss: 0.0089 - accuracy: 0.9980 - val_loss: 0.1661 - val_accuracy: 0.9617 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 24/50
#
# Epoch 24: val_accuracy did not improve from 0.96708
# 281/281 - 52s - loss: 0.0105 - accuracy: 0.9970 - val_loss: 0.1457 - val_accuracy: 0.9662 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 25/50
#
# Epoch 25: val_accuracy improved from 0.96708 to 0.96753, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 53s - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.1414 - val_accuracy: 0.9675 - lr: 1.0000e-04 - 53s/epoch - 188ms/step
# Epoch 26/50
#
# Epoch 26: val_accuracy improved from 0.96753 to 0.97286, saving model to efficientnetV2B2_best_model.h5
# 281/281 - 53s - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.1225 - val_accuracy: 0.9729 - lr: 1.0000e-04 - 53s/epoch - 189ms/step
# Epoch 27/50
#
# Epoch 27: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0053 - accuracy: 0.9982 - val_loss: 0.1696 - val_accuracy: 0.9600 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 28/50
#
# Epoch 28: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.1430 - val_accuracy: 0.9684 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 29/50
#
# Epoch 29: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0086 - accuracy: 0.9978 - val_loss: 0.1583 - val_accuracy: 0.9635 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 30/50
#
# Epoch 30: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0125 - accuracy: 0.9967 - val_loss: 0.1902 - val_accuracy: 0.9586 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 31/50
#
# Epoch 31: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.1664 - val_accuracy: 0.9622 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 32/50
#
# Epoch 32: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.1411 - val_accuracy: 0.9631 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 33/50
#
# Epoch 33: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.1743 - val_accuracy: 0.9653 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 34/50
#
# Epoch 34: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.1367 - val_accuracy: 0.9666 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 35/50
#
# Epoch 35: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.1493 - val_accuracy: 0.9666 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 36/50
#
# Epoch 36: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.1422 - val_accuracy: 0.9706 - lr: 1.0000e-04 - 52s/epoch - 184ms/step
# Epoch 37/50
#
# Epoch 37: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.1786 - val_accuracy: 0.9671 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 38/50
#
# Epoch 38: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.1484 - val_accuracy: 0.9711 - lr: 1.0000e-04 - 52s/epoch - 184ms/step
# Epoch 39/50
#
# Epoch 39: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.1468 - val_accuracy: 0.9720 - lr: 1.0000e-04 - 52s/epoch - 184ms/step
# Epoch 40/50
#
# Epoch 40: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.1291 - val_accuracy: 0.9729 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 41/50
#
# Epoch 41: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.1317 - val_accuracy: 0.9715 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 42/50
#
# Epoch 42: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.1565 - val_accuracy: 0.9684 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 43/50
#
# Epoch 43: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.1323 - val_accuracy: 0.9706 - lr: 1.0000e-04 - 52s/epoch - 184ms/step
# Epoch 44/50
#
# Epoch 44: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.1335 - val_accuracy: 0.9698 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# Epoch 45/50
#
# Epoch 45: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.1453 - val_accuracy: 0.9698 - lr: 1.0000e-04 - 52s/epoch - 184ms/step
# Epoch 46/50
#
# Epoch 46: val_accuracy did not improve from 0.97286
# 281/281 - 52s - loss: 0.0059 - accuracy: 0.9984 - val_loss: 0.1503 - val_accuracy: 0.9720 - lr: 1.0000e-04 - 52s/epoch - 185ms/step
# 71/71 - 4s - 4s/epoch - 59ms/step

# %%
mkdir output

# %%
cp -r './1_output_imagenet_all_layer_trained' '/content/drive/MyDrive/Colab Notebooks/pravin_thesis/2_Image_classification/4_efficientNetV2B2'
